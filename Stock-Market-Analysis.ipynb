# %% [markdown]
# # **Stock Market Analysis**

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas_datareader as datareader
# %matplotlib inline 
import datetime as dt

# %%
start = dt.datetime(2021,10,1)
end = dt.datetime(2022,11,2)

# %%
# Amazon Analysis
df = datareader.DataReader('AMZN','yahoo',start,end)
df.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-09-30  166.392502  163.699493  165.800003  164.251999  56848000.0
# 2021-10-01  165.458496  162.796997  164.450500  164.162994  56712000.0
# 2021-10-04  163.999496  158.812500  163.969498  159.488998  90462000.0
# 2021-10-05  163.036499  160.123001  160.225006  161.050003  65384000.0
# 2021-10-06  163.216995  159.931000  160.676498  163.100494  50660000.0
#
#              Adj Close
# Date
# 2021-09-30  164.251999
# 2021-10-01  164.162994
# 2021-10-04  159.488998
# 2021-10-05  161.050003
# 2021-10-06  163.100494

# %%
df.tail()
# Out:
#                   High         Low        Open       Close       Volume  \
# Date
# 2022-10-27  114.120003  109.769997  113.919998  110.959999  129605400.0
# 2022-10-28  103.959999   97.660004   97.910004  103.410004  223133400.0
# 2022-10-31  104.870003  100.739998  103.559998  102.440002   99251400.0
# 2022-11-01  104.580002   96.059998  103.989998   96.790001  153370000.0
# 2022-11-02   97.739998   92.010002   97.320000   92.120003  135761800.0
#
#              Adj Close
# Date
# 2022-10-27  110.959999
# 2022-10-28  103.410004
# 2022-10-31  102.440002
# 2022-11-01   96.790001
# 2022-11-02   92.120003

# %%
df.dtypes
# Out:
# High         float64
# Low          float64
# Open         float64
# Close        float64
# Volume       float64
# Adj Close    float64
# dtype: object

# %%
df.columns
# Out:
# Index(['High', 'Low', 'Open', 'Close', 'Volume', 'Adj Close'], dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 276 entries, 2021-09-30 to 2022-11-02
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   High       276 non-null    float64
#  1   Low        276 non-null    float64
#  2   Open       276 non-null    float64
#  3   Close      276 non-null    float64
#  4   Volume     276 non-null    float64
#  5   Adj Close  276 non-null    float64
# dtypes: float64(6)
# memory usage: 15.1 KB

# %%
df.shape
# Out:
# (276, 6)

# %%
#print(df.to_string())

# %%
df.size
# Out:
# 1656

# %%
 # cleaning

# %%
sum_close = df['Close'].sum()

# %%
sum_adj = df['Adj Close'].sum()

# %%
print('THE DIFFERENCE BETWEEN CLOSE AND ADJ CLOSE =',sum_close-sum_adj)
# Out:
# THE DIFFERENCE BETWEEN CLOSE AND ADJ CLOSE = 0.0

# %%
# Hence we know that the difference between 'close' and 'adj close' is zero so we can conclude both the columns are same 
# we can drop adj close column

# %%
df = df.drop('Adj Close',axis=1)

# %%
df.head(2)
# Out:
#                   High         Low        Open       Close      Volume
# Date
# 2021-09-30  166.392502  163.699493  165.800003  164.251999  56848000.0
# 2021-10-01  165.458496  162.796997  164.450500  164.162994  56712000.0

# %%
#plt.figure(figsize=(20,5),dpi=200)
#df['Volume'].plot();

# %%
# We WillCheck What was the change in stock price over time

# %%
df.Close
# Out:
# Date
# 2021-09-30    164.251999
# 2021-10-01    164.162994
# 2021-10-04    159.488998
# 2021-10-05    161.050003
# 2021-10-06    163.100494
#                  ...
# 2022-10-27    110.959999
# 2022-10-28    103.410004
# 2022-10-31    102.440002
# 2022-11-01     96.790001
# 2022-11-02     92.120003
# Name: Close, Length: 276, dtype: float64

# %%
df.describe()
# Out:
#              High         Low        Open       Close        Volume
# count  276.000000  276.000000  276.000000  276.000000  2.760000e+02
# mean   144.169321  139.608348  141.958321  141.803500  7.222678e+07
# std     23.797705   24.055756   23.966872   23.900741  3.270888e+07
# min     97.739998   92.010002   97.320000   92.120003  3.575400e+07
# 25%    121.072502  115.993750  118.435001  118.457500  5.247125e+07
# 50%    145.065002  140.340004  142.875000  142.934998  6.280930e+07
# 75%    166.180630  162.836124  164.224754  164.223503  8.108058e+07
# max    188.107498  183.785995  185.634506  184.802994  2.726620e+08

# %%
change_in_price = df['Close'].pct_change(freq='M')

# %%
change_in_price = pd.DataFrame(change_in_price.dropna())

# %%
# change in stock price over time
change_in_price
# Out:
#                Close
# Date
# 2021-11-30  0.056948
# 2021-12-31 -0.049252
# 2022-01-31 -0.102830
# 2022-02-28  0.026673
# 2022-03-31  0.061437
# 2022-05-31 -0.034462
# 2022-06-30 -0.116459
# 2022-08-31 -0.063668
# 2022-09-30 -0.108622
# 2022-10-31 -0.093451

# %%
# change in stock price over time Visualization
#plt.figure(figsize=(20,5),dpi=200)
#change_in_price['Close'].plot();

# %%
# change in stock price over time Visualization
plt.figure(figsize=(20,5),dpi=200)
df['Close'].plot();

# %%
# Visualizeing the change in a stock’s volume being traded, over time
plt.figure(figsize=(20,5),dpi=200)
df['Volume'].plot();

# %%
# moving average of stock

# %%
plt.figure(figsize=(20,5),dpi=200)
df['MA20'] = df['Open'].rolling(20).mean()
df['Close'].plot(figsize = (20,7))
df['MA20'].plot();

# %%
# What was the daily return average of a stock

# %%
roi = df['Close'].pct_change()

# %%
avg = roi.mean()
print('The Average Daily Return Of Stock =', avg)
# Out:
# The Average Daily Return Of Stock = -0.0016783027534871798

# %%
# new column ‘Trend’ whose values are based on the 'Daily Return'
df['Trend']=roi
df = df.drop('MA20',axis=1)

# %%
df.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-09-30  166.392502  163.699493  165.800003  164.251999  56848000.0
# 2021-10-01  165.458496  162.796997  164.450500  164.162994  56712000.0
# 2021-10-04  163.999496  158.812500  163.969498  159.488998  90462000.0
# 2021-10-05  163.036499  160.123001  160.225006  161.050003  65384000.0
# 2021-10-06  163.216995  159.931000  160.676498  163.100494  50660000.0
#
#                Trend
# Date
# 2021-09-30       NaN
# 2021-10-01 -0.000542
# 2021-10-04 -0.028472
# 2021-10-05  0.009788
# 2021-10-06  0.012732

# %%
# Trend Visualizeing
plt.figure(figsize=(20,5),dpi=200)
df['Trend'].plot(colormap='RdBu');

# %%
# •Apple
# •Google
# •Microsoft
# •Amazon 
# Now we will analysis all the above stock

# %%
# We Will Read the Data from Yahoo finance website directly.
amazon = datareader.DataReader('AMZN','yahoo',start,end)
amazon.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-09-30  166.392502  163.699493  165.800003  164.251999  56848000.0
# 2021-10-01  165.458496  162.796997  164.450500  164.162994  56712000.0
# 2021-10-04  163.999496  158.812500  163.969498  159.488998  90462000.0
# 2021-10-05  163.036499  160.123001  160.225006  161.050003  65384000.0
# 2021-10-06  163.216995  159.931000  160.676498  163.100494  50660000.0
#
#              Adj Close
# Date
# 2021-09-30  164.251999
# 2021-10-01  164.162994
# 2021-10-04  159.488998
# 2021-10-05  161.050003
# 2021-10-06  163.100494

# %%
google = datareader.DataReader('GOOGL','yahoo',start,end)
google.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-09-30  135.542496  133.556000  134.261505  133.675995  37996000.0
# 2021-10-01  136.910507  134.072998  134.447495  136.542999  35360000.0
# 2021-10-04  135.960495  131.050003  135.960495  133.659500  51202000.0
# 2021-10-05  137.224503  134.041000  134.041000  136.022995  32404000.0
# 2021-10-06  137.750000  134.550003  134.750000  137.565002  24364000.0
#
#              Adj Close
# Date
# 2021-09-30  133.675995
# 2021-10-01  136.542999
# 2021-10-04  133.659500
# 2021-10-05  136.022995
# 2021-10-06  137.565002

# %%
microsoft = datareader.DataReader('MSFT','yahoo',start,end)
microsoft.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-09-30  287.829987  281.619995  285.709991  281.920013  32343600.0
# 2021-10-01  289.980011  281.290009  282.119995  289.100006  30086300.0
# 2021-10-04  287.750000  280.250000  287.399994  283.109985  31350700.0
# 2021-10-05  290.399994  284.049988  284.049988  288.760010  24993000.0
# 2021-10-06  293.630005  285.510010  285.779999  293.109985  28002600.0
#
#              Adj Close
# Date
# 2021-09-30  279.578522
# 2021-10-01  286.698883
# 2021-10-04  280.758606
# 2021-10-05  286.361725
# 2021-10-06  290.675568

# %%
apple = datareader.DataReader('AAPL','yahoo',start,end)
apple.head()
# Out:
#                   High         Low        Open       Close      Volume  \
# Date
# 2021-09-30  144.380005  141.279999  143.660004  141.500000  89056700.0
# 2021-10-01  142.919998  139.110001  141.899994  142.649994  94639600.0
# 2021-10-04  142.210007  138.270004  141.759995  139.139999  98322000.0
# 2021-10-05  142.240005  139.360001  139.490005  141.110001  80861100.0
# 2021-10-06  142.149994  138.369995  139.470001  142.000000  83221100.0
#
#              Adj Close
# Date
# 2021-09-30  140.478500
# 2021-10-01  141.620163
# 2021-10-04  138.135513
# 2021-10-05  140.091309
# 2021-10-06  140.974869

# %%
data = pd.concat([google,amazon,microsoft,apple,],keys=['GOOGLE', 'AMAZON', 'MICROSOFT', 'APPLE'], axis=1)
data.head()
# Out:
#                 GOOGLE                                                  \
#                   High         Low        Open       Close      Volume
# Date
# 2021-09-30  135.542496  133.556000  134.261505  133.675995  37996000.0
# 2021-10-01  136.910507  134.072998  134.447495  136.542999  35360000.0
# 2021-10-04  135.960495  131.050003  135.960495  133.659500  51202000.0
# 2021-10-05  137.224503  134.041000  134.041000  136.022995  32404000.0
# 2021-10-06  137.750000  134.550003  134.750000  137.565002  24364000.0
#
#                             AMAZON                                      ...  \
#              Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2021-09-30  133.675995  166.392502  163.699493  165.800003  164.251999  ...
# 2021-10-01  136.542999  165.458496  162.796997  164.450500  164.162994  ...
# 2021-10-04  133.659500  163.999496  158.812500  163.969498  159.488998  ...
# ...

# %%
data.columns
# Out:
# MultiIndex([(   'GOOGLE',      'High'),
#             (   'GOOGLE',       'Low'),
#             (   'GOOGLE',      'Open'),
#             (   'GOOGLE',     'Close'),
#             (   'GOOGLE',    'Volume'),
#             (   'GOOGLE', 'Adj Close'),
#             (   'AMAZON',      'High'),
#             (   'AMAZON',       'Low'),
#             (   'AMAZON',      'Open'),
#             (   'AMAZON',     'Close'),
#             (   'AMAZON',    'Volume'),
#             (   'AMAZON', 'Adj Close'),
#             ('MICROSOFT',      'High'),
#             ('MICROSOFT',       'Low'),
#             ('MICROSOFT',      'Open'),
#             ('MICROSOFT',     'Close'),
#             ('MICROSOFT',    'Volume'),
#             ('MICROSOFT', 'Adj Close'),
#             (    'APPLE',      'High'),
#             (    'APPLE',       'Low'),
#             (    'APPLE',      'Open'),
#             (    'APPLE',     'Close'),
#             (    'APPLE',    'Volume'),
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 276 entries, 2021-09-30 to 2022-11-02
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   (GOOGLE, High)          276 non-null    float64
#  1   (GOOGLE, Low)           276 non-null    float64
#  2   (GOOGLE, Open)          276 non-null    float64
#  3   (GOOGLE, Close)         276 non-null    float64
#  4   (GOOGLE, Volume)        276 non-null    float64
#  5   (GOOGLE, Adj Close)     276 non-null    float64
#  6   (AMAZON, High)          276 non-null    float64
#  7   (AMAZON, Low)           276 non-null    float64
#  8   (AMAZON, Open)          276 non-null    float64
#  9   (AMAZON, Close)         276 non-null    float64
#  10  (AMAZON, Volume)        276 non-null    float64
#  11  (AMAZON, Adj Close)     276 non-null    float64
#  12  (MICROSOFT, High)       276 non-null    float64
# ...

# %%
data.size
# Out:
# 6624

# %%
data.shape
# Out:
# (276, 24)

# %%
data.describe()
# Out:
#            GOOGLE                                                    \
#              High         Low        Open       Close        Volume
# count  276.000000  276.000000  276.000000  276.000000  2.760000e+02
# mean   126.410104  123.146375  124.831862  124.720451  3.441253e+07
# std     16.366295   16.440909   16.532838   16.447243  1.355964e+07
# min     91.180000   86.879997   90.940002   86.970001  1.568800e+07
# 25%    113.249374  109.903625  111.418003  111.529999  2.594200e+07
# 50%    129.976501  125.114250  126.612999  126.554253  3.209500e+07
# 75%    141.518124  138.694500  139.519249  139.748371  3.933300e+07
# max    151.546494  148.899002  151.250000  149.838501  1.232000e+08
#
#                        AMAZON                                      ...  \
#         Adj Close        High         Low        Open       Close  ...
# count  276.000000  276.000000  276.000000  276.000000  276.000000  ...
# mean   124.720451  144.169321  139.608348  141.958321  141.803500  ...
# ...

# %%
# We Will Check What was the change in stock price over time

# %%
change_in_stock_price_google = data['GOOGLE','Adj Close'].pct_change(freq='M')
change_in_stock_price_google = pd.DataFrame(change_in_stock_price_google.dropna())
print(change_in_stock_price_google)

change_in_stock_price_amazon = data['AMAZON','Adj Close'].pct_change(freq='M')
change_in_stock_price_amazon = pd.DataFrame(change_in_stock_price_amazon.dropna())
print(change_in_stock_price_amazon)

change_in_stock_price_microsoft = data['MICROSOFT','Adj Close'].pct_change(freq='M')
change_in_stock_price_microsoft = pd.DataFrame(change_in_stock_price_microsoft.dropna())
print(change_in_stock_price_microsoft)

change_in_stock_price_apple = data['APPLE','Adj Close'].pct_change(freq='M')
change_in_stock_price_apple = pd.DataFrame(change_in_stock_price_apple.dropna())
print(change_in_stock_price_apple)
# Out:
#               GOOGLE
#            Adj Close
# Date
# 2021-11-30 -0.011146
# 2021-12-31  0.020821
# 2022-01-31 -0.065919
# 2022-02-28 -0.001822
# 2022-03-31  0.029695
# 2022-05-31 -0.024197
# 2022-06-30 -0.042185
# 2022-08-31 -0.057810
# 2022-09-30 -0.116152
# 2022-10-31 -0.011918
#               AMAZON
#            Adj Close
# Date
# 2021-11-30  0.056948
# 2021-12-31 -0.049252
# 2022-01-31 -0.102830
# 2022-02-28  0.026673
# 2022-03-31  0.061437
# 2022-05-31 -0.034462
# 2022-06-30 -0.116459
# 2022-08-31 -0.063668
# 2022-09-30 -0.108622
# 2022-10-31 -0.093451
#            MICROSOFT
#            Adj Close
# Date
# 2021-11-30  0.005540
# 2021-12-31  0.017333
# 2022-01-31 -0.075345
# 2022-02-28 -0.037212
# 2022-03-31  0.031862
# 2022-05-31 -0.042067
# 2022-06-30 -0.055321
# 2022-08-31 -0.057498
# 2022-09-30 -0.109267
# 2022-10-31 -0.003306
#                APPLE
#            Adj Close
# Date
# 2021-11-30  0.111313
# 2021-12-31  0.074229
# 2022-01-31 -0.015712
# 2022-02-28 -0.054066
# ...

# %%
change_in_stock_data = pd.concat([change_in_stock_price_google,change_in_stock_price_amazon,change_in_stock_price_microsoft,change_in_stock_price_apple,], axis=1)
change_in_stock_data
# Out:
#               GOOGLE    AMAZON MICROSOFT     APPLE
#            Adj Close Adj Close Adj Close Adj Close
# Date
# 2021-11-30 -0.011146  0.056948  0.005540  0.111313
# 2021-12-31  0.020821 -0.049252  0.017333  0.074229
# 2022-01-31 -0.065919 -0.102830 -0.075345 -0.015712
# 2022-02-28 -0.001822  0.026673 -0.037212 -0.054066
# 2022-03-31  0.029695  0.061437  0.031862  0.057473
# 2022-05-31 -0.024197 -0.034462 -0.042067 -0.056352
# 2022-06-30 -0.042185 -0.116459 -0.055321 -0.081430
# 2022-08-31 -0.057810 -0.063668 -0.057498 -0.025210
# 2022-09-30 -0.116152 -0.108622 -0.109267 -0.120977
# 2022-10-31 -0.011918 -0.093451 -0.003306  0.109551

# %%
# Now We Will Visualize the change in a stock’s volume being traded, over time
plt.figure(figsize=(20,5),dpi=200)
data['APPLE','Volume'].plot();

# %%
data.head(5)
# Out:
#                 GOOGLE                                                  \
#                   High         Low        Open       Close      Volume
# Date
# 2021-09-30  135.542496  133.556000  134.261505  133.675995  37996000.0
# 2021-10-01  136.910507  134.072998  134.447495  136.542999  35360000.0
# 2021-10-04  135.960495  131.050003  135.960495  133.659500  51202000.0
# 2021-10-05  137.224503  134.041000  134.041000  136.022995  32404000.0
# 2021-10-06  137.750000  134.550003  134.750000  137.565002  24364000.0
#
#                             AMAZON                                      ...  \
#              Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2021-09-30  133.675995  166.392502  163.699493  165.800003  164.251999  ...
# 2021-10-01  136.542999  165.458496  162.796997  164.450500  164.162994  ...
# 2021-10-04  133.659500  163.999496  158.812500  163.969498  159.488998  ...
# ...

# %%
# Now We Will Visualize the change in a stock’s volume being traded, over time
y1=data['GOOGLE','Volume']
y2=data['AMAZON','Volume']
y3=data['MICROSOFT','Volume']
y4=data['APPLE','Volume']
fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(figsize=(15,6),nrows=2,ncols=2,dpi=200) 
ax1.plot(y1,'r') 
ax2.plot(y2,'r') 
ax3.plot(y3,'r') 
ax4.plot(y4,'r')

ax1.set(title='GOOGLE',ylabel='Volume Frequency')
ax2.set(title='AMAZON',ylabel='Volume Frequency') 
ax3.set(title='MICROSOFT',ylabel='Volume Frequency') 
ax4.set(title='APPLE',ylabel='Volume Frequency')

plt.tight_layout()

fig.suptitle('Volume Being Traded',fontsize=16,fontweight='bold');

# %%
#Moving average of Google
plt.figure(figsize=(20,5),dpi=200)
data['MA20'] = data['GOOGLE','Adj Close'].rolling(20).mean()
data['GOOGLE','Adj Close'].plot(figsize = (20,7))
data['MA20'].plot();

# %%
#Moving average of Amazon
plt.figure(figsize=(20,5),dpi=200)
data['MA20'] = data['AMAZON','Adj Close'].rolling(20).mean()
data['AMAZON','Adj Close'].plot(figsize = (20,7))
data['MA20'].plot();

# %%
#Moving average of Microsoft
plt.figure(figsize=(20,5),dpi=200)
data['MA20'] = data['MICROSOFT','Adj Close'].rolling(20).mean()
data['MICROSOFT','Adj Close'].plot(figsize = (20,7))
data['MA20'].plot();

# %%
#Moving average of Apple
plt.figure(figsize=(20,5),dpi=200)
data['MA20'] = data['APPLE','Adj Close'].rolling(20).mean()
data['APPLE','Adj Close'].plot(figsize = (20,7))
data['MA20'].plot();

# %%
# We Will Calculate What was the daily return average of a stock

# %%
roi_google = data['GOOGLE','Adj Close'].pct_change()
roi_amazon = data['AMAZON','Adj Close'].pct_change()
roi_microsoft = data['MICROSOFT','Adj Close'].pct_change()
roi_apple = data['APPLE','Adj Close'].pct_change()

# %%
avg_google = roi_google.mean()
avg_amazon = roi_amazon.mean()
avg_microsoft = roi_microsoft.mean()
avg_apple = roi_apple.mean()

#print('The Average Daily Return Of Google =', avg_google)
print('The Average Daily Return Of Amazon =', avg_amazon)
print('The Average Daily Return Of Microsoft =', avg_microsoft)
print('The Average Daily Return Of Apple =', avg_apple)
# Out:
# The Average Daily Return Of Amazon = -0.0016783027534871798
# The Average Daily Return Of Microsoft = -0.0006566903761427985
# The Average Daily Return Of Apple = 0.00032463289094809416

# %%
plt.figure(figsize=(20,10),dpi=200,tight_layout=True) 
roi_google.plot(legend=True)
roi_amazon.plot(legend=True)
roi_microsoft.plot(legend=True)
roi_apple.plot(legend=True);

# %%
# We Will Add new column ‘Trend’ whose values are based on the 'Daily Return'

# %%
data['Google Trend']=roi_google
data['Amazon Trend']=roi_amazon
data['Microsoft Trend']=roi_microsoft
data['Apple Trend']=roi_apple

data.head(3)
# Out:
#                 GOOGLE                                                  \
#                   High         Low        Open       Close      Volume
# Date
# 2021-09-30  135.542496  133.556000  134.261505  133.675995  37996000.0
# 2021-10-01  136.910507  134.072998  134.447495  136.542999  35360000.0
# 2021-10-04  135.960495  131.050003  135.960495  133.659500  51202000.0
#
#                             AMAZON                                      ...  \
#              Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2021-09-30  133.675995  166.392502  163.699493  165.800003  164.251999  ...
# 2021-10-01  136.542999  165.458496  162.796997  164.450500  164.162994  ...
# 2021-10-04  133.659500  163.999496  158.812500  163.969498  159.488998  ...
#
#                  APPLE                                                 MA20  \
# ...

# %%
#data.columns

# %%
data = data.drop('MA20',axis=1)
data.head()
# Out:
#                 GOOGLE                                                  \
#                   High         Low        Open       Close      Volume
# Date
# 2021-09-30  135.542496  133.556000  134.261505  133.675995  37996000.0
# 2021-10-01  136.910507  134.072998  134.447495  136.542999  35360000.0
# 2021-10-04  135.960495  131.050003  135.960495  133.659500  51202000.0
# 2021-10-05  137.224503  134.041000  134.041000  136.022995  32404000.0
# 2021-10-06  137.750000  134.550003  134.750000  137.565002  24364000.0
#
#                             AMAZON                                      ...  \
#              Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2021-09-30  133.675995  166.392502  163.699493  165.800003  164.251999  ...
# 2021-10-01  136.542999  165.458496  162.796997  164.450500  164.162994  ...
# 2021-10-04  133.659500  163.999496  158.812500  163.969498  159.488998  ...
# ...

# %%
data= data.fillna(0)
data.head()
# Out:
#                 GOOGLE                                                  \
#                   High         Low        Open       Close      Volume
# Date
# 2021-09-30  135.542496  133.556000  134.261505  133.675995  37996000.0
# 2021-10-01  136.910507  134.072998  134.447495  136.542999  35360000.0
# 2021-10-04  135.960495  131.050003  135.960495  133.659500  51202000.0
# 2021-10-05  137.224503  134.041000  134.041000  136.022995  32404000.0
# 2021-10-06  137.750000  134.550003  134.750000  137.565002  24364000.0
#
#                             AMAZON                                      ...  \
#              Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2021-09-30  133.675995  166.392502  163.699493  165.800003  164.251999  ...
# 2021-10-01  136.542999  165.458496  162.796997  164.450500  164.162994  ...
# 2021-10-04  133.659500  163.999496  158.812500  163.969498  159.488998  ...
# ...

# %%
# We Will Visualize trend frequency through a Pie Chart.

# %%
stats=data['Google Trend'].describe()
stats = stats['min'],stats['max'],stats['mean']
stats = pd.DataFrame(stats,index=['Down Trend','Up Trend','Average'],columns=['GOOGLE'])
stats=abs(stats)
stats
# Out:
#               GOOGLE
# Down Trend  0.091405
# Up Trend    0.076557
# Average     0.001302

# %%
fig,ax=plt.subplots(figsize=(5,5))
stats.plot(kind='pie',
        subplots=True,
          ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# With the below figure we can understand the overall trend

# %%
stats_amz =data['Amazon Trend'].describe()
stats_amz = stats_amz['min'],stats_amz['max'],stats_amz['mean']
stats_amz = pd.DataFrame(stats_amz,index=['Down Trend','Up Trend','Average'],columns=['AMAZON'])
stats_amz=abs(stats_amz)

stats_m=data['Microsoft Trend'].describe()
stats_m = stats_m['min'],stats_m['max'],stats_m['mean']
stats_m = pd.DataFrame(stats_m,index=['Down Trend','Up Trend','Average'],columns=['MICROSOFT'])
stats_m=abs(stats_m)

stats_a=data['Apple Trend'].describe()
stats_a = stats_a['min'],stats_a['max'],stats_a['mean']
stats_a = pd.DataFrame(stats_a,index=['Down Trend','Up Trend','Average'],columns=['APPLE'])
stats_a=abs(stats_a)

# %%
fig,ax=plt.subplots(figsize=(5,5))
stats_amz.plot(kind='pie',
        subplots=True,
          ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
fig,ax=plt.subplots(figsize=(5,5))
stats_m.plot(kind='pie',
        subplots=True,
          ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
fig,ax=plt.subplots(figsize=(5,5))
stats_a.plot(kind='pie',
        subplots=True,
          ax=ax)
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
fig,((ax1,ax2),(ax3,ax4))=plt.subplots(figsize=(15,6),nrows=2,ncols=2,dpi=200)
stats.plot(kind='pie',
        subplots=True,
          ax=ax1)
ax1.legend(loc='center left', bbox_to_anchor=(1, 0.5))


stats_amz.plot(kind='pie',
        subplots=True,
          ax=ax2)
ax2.legend(loc='center left', bbox_to_anchor=(1, 0.5))


stats_m.plot(kind='pie',
        subplots=True,
          ax=ax3)
ax3.legend(loc='center left', bbox_to_anchor=(1, 0.5))


stats_a.plot(kind='pie',
        subplots=True,
          ax=ax4)
ax4.legend(loc='center left', bbox_to_anchor=(1, 0.5));

# %%
# We Will Check What was the correlation between the daily returns of different stocks

# %%
#sns.heatmap(data);

# %%
data.head()
# Out:
#                 GOOGLE                                                  \
#                   High         Low        Open       Close      Volume
# Date
# 2021-09-30  135.542496  133.556000  134.261505  133.675995  37996000.0
# 2021-10-01  136.910507  134.072998  134.447495  136.542999  35360000.0
# 2021-10-04  135.960495  131.050003  135.960495  133.659500  51202000.0
# 2021-10-05  137.224503  134.041000  134.041000  136.022995  32404000.0
# 2021-10-06  137.750000  134.550003  134.750000  137.565002  24364000.0
#
#                             AMAZON                                      ...  \
#              Adj Close        High         Low        Open       Close  ...
# Date                                                                    ...
# 2021-09-30  133.675995  166.392502  163.699493  165.800003  164.251999  ...
# 2021-10-01  136.542999  165.458496  162.796997  164.450500  164.162994  ...
# 2021-10-04  133.659500  163.999496  158.812500  163.969498  159.488998  ...
# ...

# %%
daily_return=pd.concat([roi_google,roi_amazon,roi_microsoft,roi_apple],axis=1)
daily_return.head()
# Out:
#               GOOGLE    AMAZON MICROSOFT     APPLE
#            Adj Close Adj Close Adj Close Adj Close
# Date
# 2021-09-30       NaN       NaN       NaN       NaN
# 2021-10-01  0.021447 -0.000542  0.025468  0.008127
# 2021-10-04 -0.021118 -0.028472 -0.020720 -0.024606
# 2021-10-05  0.017683  0.009788  0.019957  0.014159
# 2021-10-06  0.011336  0.012732  0.015064  0.006307

# %%
daily_return=daily_return.dropna()

# %%
daily_return.columns=['Google','Amazon','Microsoft','Apple']
daily_return.head()
# Out:
#               Google    Amazon  Microsoft     Apple
# Date
# 2021-10-01  0.021447 -0.000542   0.025468  0.008127
# 2021-10-04 -0.021118 -0.028472  -0.020720 -0.024606
# 2021-10-05  0.017683  0.009788   0.019957  0.014159
# 2021-10-06  0.011336  0.012732   0.015064  0.006307
# 2021-10-07  0.012067  0.012391   0.005936  0.009085

# %%
plt.figure(dpi=200);
sns.pairplot(daily_return);

# %%
corr_data = daily_return.corr(method='pearson')
corr_data.head().reset_index()
corr_data.head()
# Out:
#              Google    Amazon  Microsoft     Apple
# Google     1.000000  0.693110   0.839143  0.751774
# Amazon     0.693110  1.000000   0.697209  0.657046
# Microsoft  0.839143  0.697209   1.000000  0.791034
# Apple      0.751774  0.657046   0.791034  1.000000

# %%
plt.figure(dpi=200)
sns.heatmap(corr_data, cmap='RdYlGn', vmax=1.0, vmin=-1.0 , mask = mask, linewidths=2.5)
plt.yticks(rotation=0) 
plt.xticks(rotation=90) 
plt.show()
